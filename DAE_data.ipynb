# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import seaborn as sns

# %%
df = pd.read_csv('project_data.csv', sep=',',encoding = "ISO-8859-1")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-e80914788b50> in <module>
# ----> 1 df = pd.read_csv('project_data.csv', sep=',',encoding = "ISO-8859-1")
#
# /usr/lib/python3/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
df_filtered = df.loc[df['Q14AGE'] > 18]
df_filtered.head(20)
# Out:
#                   UQNO  PERSONNO      Province Q12NIGHTS Q13GENDER  Q14AGE  \
# 0   160100720000003201         1  Western Cape       Yes      Male      31
# 1   160100720000003201         2  Western Cape       Yes    Female      27
# 5   160100720000006901         1  Western Cape       Yes    Female      31
# 10  160100720000010601         1  Western Cape       Yes      Male      24
# 11  160100880000001201         1  Western Cape       Yes      Male      33
# 12  160100880000001201         2  Western Cape       Yes    Female      35
# 14  160100880000003201         1  Western Cape       Yes    Female      84
# 15  160100880000005201         1  Western Cape       Yes      Male      49
# 16  160100880000005201         2  Western Cape       Yes    Female      41
# 19  160100880000007201         2  Western Cape       Yes    Female      56
# 20  160100880000009201         1  Western Cape       Yes      Male      46
# ...

# %%
edu_lvl = df_filtered.Education_Status
plt.figure(figsize=(12,8))
plt.hist(edu_lvl)
plt.xticks(rotation = 45)
plt.show()

# %%
pop = df_filtered['Q15POPULATION']
plt.hist(pop)
# Out:
# (array([ 16202.,      0.,      0., 137552.,      0.,      0.,  12419.,
#              0.,      0.,   4206.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
age = df_filtered.Q14AGE
plt.hist(age)
# Out:
# (array([4.3522e+04, 4.0781e+04, 3.0534e+04, 2.4320e+04, 1.7796e+04,
#         9.1340e+03, 3.4300e+03, 7.8700e+02, 6.8000e+01, 7.0000e+00]),
#  array([ 19. ,  28.9,  38.8,  48.7,  58.6,  68.5,  78.4,  88.3,  98.2,
#         108.1, 118. ]),
#  <BarContainer object of 10 artists>)

# %%
job= df_filtered.Q33HAVEJOB.astype(str)
plt.hist(job)
# Out:
# (array([99256.,     0.,     0.,     0.,     0., 70925.,     0.,     0.,
#             0.,   198.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
emp= df_filtered.Q58SALARYCATEGORY.astype(str)
plt.figure(figsize=(12,8))
plt.hist(emp)
plt.xticks(rotation = 45)
plt.show()
